# %% [markdown]
# <a href="https://colab.research.google.com/github/SparkingNovaXD/Rvc2/blob/main/notebooks/ultimate_rvc_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Colab for [Ultimate RVC](https://github.com/JackismyShephard/ultimate-rvc)
#
# This Colab notebook will **help** you if you don’t have a GPU or if your PC isn’t very powerful.
#
# Simply click `Runtime` in the top navigation bar and `Run all`. Wait for the output of the final cell to show the public gradio url and click on it.
#
# NOTE: If Ultimate RVC is running too slowly with the default sharing method (gradio), consider instead selecting "ngrok" as sharing method.
# This method requires supplying an access token, which you can find on [ngrok](https://ngrok.com/) after creating a personal account.
# The ngrok link output in the final cell will lead you to a new site which will redirect you to Ultimate RVC.

# %%
# @title 0: Initialize notebook
# %pip install ipython-autotime pyngrok
# %load_ext autotime

import codecs
import os
import time
from pathlib import Path
from urllib import request

import ipywidgets as widgets
from IPython.display import clear_output
from IPython.display import display as i_display
from pyngrok import ngrok

clear_output()
# Out:
# time: 5.46 s (started: 2026-03-09 11:38:38 +00:00)

# %%
# @title 1: Clone repository
cloneing = codecs.decode(
    "uggcf://tvguho.pbz/WnpxvfzlFurcuneq/hygvzngr-eip.tvg",
    "rot_13",
)

# !git clone $cloneing HRVC
# %cd /content/HRVC
clear_output()
# Out:
# time: 113 ms (started: 2026-03-09 11:38:44 +00:00)

# %%
# @title 2: Install dependencies

light = codecs.decode("uggcf://nfgeny.fu/hi/0.9.11/vafgnyy.fu", "rot_13")
inits = codecs.decode("./fep/hygvzngr_eip/pber/znva.cl", "rot_13")
prerelease = "--prerelease if-necessary-or-explicit"

# !apt install -y python3-dev unzip
# !curl -LsSf $light | sh

os.environ["URVC_CONSOLE_LOG_LEVEL"] = "WARNING"

# !uv run -q $prerelease $inits
# !uv add $prerelease matplotlib-inline==0.1.7
clear_output()
# Out:
# time: 13.2 s (started: 2026-03-09 11:38:44 +00:00)

# %%
# @title 3: Run Ultimate RVC
# @markdown  #### Choose a sharing method:

import codecs

method = "gradio"  # @param ["gradio",  "ngrok", "cloudflared","localtunnel"]
ngrok_token = ""  # @param {type:"string"}
runpice = codecs.decode("./fep/hygvzngr_eip/jro/znva.cl", "rot_13")

if method == "gradio":
    # !uv run $prerelease $runpice --share
elif method == "ngrok":
    try:
        ngrok.set_auth_token(ngrok_token)
        ngrok.kill()
        tunnel = ngrok.connect(6969)
        print(f"Ngrok URL: {tunnel.public_url}")
        # !uv run $prerelease $runpice --listen-port 6969
    except Exception as e:  # noqa: BLE001
        print(f"Error starting ngrok: {e}")
elif method == "cloudflared":
    # !curl -LO https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
    # !dpkg -i cloudflared-linux-amd64.deb
    clear_output()
    # !rm -rf nohup.out
    # !nohup cloudflared tunnel --url localhost:6969 &
    clear_output()
    time.sleep(10)
    cloudflare_url = !grep -oE "https://[a-zA-Z0-9.-]+\.trycloudflare\.com" nohup.out
    print(f"URVC Public URL: {cloudflare_url}")
    # !uv run $prerelease $runpice --listen-port 6969
elif method == "localtunnel":
    # !npm install -g localtunnel &>/dev/null
    Path("url.txt").open("w", encoding="utf-8").close()
    # !lt --port 6969 >> url.txt 2>&1 &
    time.sleep(2)
    endpoint_ip = (
        request.urlopen("https://ipv4.icanhazip.com").read().decode("utf8").strip("\n")
    )
    tunnel_url = (
        Path("url.txt").read_text(encoding="utf-8").replace("your url is: ", "")
    )
    print(f"Share Link: {tunnel_url}")
    password_endpoint_widget = widgets.Text(
        value=endpoint_ip,
        description="Password IP:",
        disabled=True,
    )
    i_display(password_endpoint_widget)
    # !uv run $prerelease $runpice --listen-port 6969
# Out:
# Bytecode compiled 19382 files in 1.59s
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://721fe090173624d313.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Traceback (most recent call last):
#   File "/content/HRVC/src/ultimate_rvc/web/common.py", line 70, in _wrapped_fn
#     res = fn(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/src/ultimate_rvc/core/manage/models.py", line 449, in upload_voice_model
#     model_dir_path = validate_model(name, Entity.VOICE_MODEL, mode="not_exists")
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/src/ultimate_rvc/core/common.py", line 461, in validate_model
#     raise ModelExistsError(entity, name=name)
# ultimate_rvc.core.exceptions.ModelExistsError: Voice model with name 'Gigi' already exists. Please provide a different name for your voice model.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/queueing.py", line 759, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/route_utils.py", line 354, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 2116, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 1623, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/anyio/to_thread.py", line 63, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 2502, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/.venv/lib/python3.12/site-packages/gradio/utils.py", line 915, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "/content/HRVC/src/ultimate_rvc/web/common.py", line 77, in _wrapped_fn
#     raise gr.Error(str(e)) from e
# gradio.exceptions.Error: "Voice model with name 'Gigi' already exists. Please provide a different name for your voice model."
# [~] Retrieving song...
# [~] Separating vocals from instrumentals...
# 4.38kiB [00:00, 10.9MiB/s]
# 15.4kiB [00:00, 30.2MiB/s]
# 2026-03-09 11:41:09 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 2/2 [00:02<00:00,  1.35s/it]
# 100% 2/2 [00:00<00:00,  4.10it/s]
# [~] Separating main vocals from backup vocals...
# 2026-03-09 11:41:16 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 2/2 [00:01<00:00,  1.03it/s]
# 100% 2/2 [00:00<00:00,  4.69it/s]
# [~] De-reverbing vocals...
# 2026-03-09 11:41:20 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 3/3 [00:01<00:00,  1.75it/s]
# 100% 3/3 [00:00<00:00,  9.82it/s]
# [~] Converting vocals...
# [~] Post-processing vocals...
# [~] Pitch-shifting instrumentals...
# [~] Pitch-shifting backup vocals...
# [~] Retrieving song...
# [~] Separating vocals from instrumentals...
# [~] Separating main vocals from backup vocals...
# [~] De-reverbing vocals...
# [~] Converting vocals...
# [~] Post-processing vocals...
# [~] Pitch-shifting instrumentals...
# [~] Pitch-shifting backup vocals...
# [~] Retrieving song...
# [~] Separating vocals from instrumentals...
# 2026-03-09 11:46:00 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 2/2 [00:02<00:00,  1.10s/it]
# 100% 2/2 [00:00<00:00,  4.41it/s]
# [~] Separating main vocals from backup vocals...
# 2026-03-09 11:46:04 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 2/2 [00:01<00:00,  1.20it/s]
# 100% 2/2 [00:00<00:00,  2.75it/s]
# [~] De-reverbing vocals...
# 2026-03-09 11:46:08 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 2/2 [00:01<00:00,  1.80it/s]
# 100% 2/2 [00:00<00:00,  8.51it/s]
# [~] Converting vocals...
# [~] Post-processing vocals...
# [~] Pitch-shifting instrumentals...
# [~] Pitch-shifting backup vocals...
# [~] Retrieving song...
# [~] Separating vocals from instrumentals...
# 2026-03-09 11:47:32 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 7/7 [00:07<00:00,  1.08s/it]
# 100% 6/6 [00:01<00:00,  4.47it/s]
# [~] Separating main vocals from backup vocals...
# 2026-03-09 11:47:44 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 7/7 [00:05<00:00,  1.30it/s]
# 100% 6/6 [00:01<00:00,  4.87it/s]
# [~] De-reverbing vocals...
# 2026-03-09 11:47:53 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 14/14 [00:08<00:00,  1.74it/s]
# 100% 10/10 [00:01<00:00,  9.15it/s]
# [~] Converting vocals...
# [~] Post-processing vocals...
# [~] Pitch-shifting instrumentals...
# [~] Pitch-shifting backup vocals...
# [~] Retrieving song...
# [~] Separating vocals from instrumentals...
# 2026-03-09 11:49:27 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 2026-03-09 11:49:27 - WARNING - audio_separator.separator.separator - Unknown audio subtype MPEG_LAYER_III, defaulting to 16-bit output
# 100% 6/6 [00:06<00:00,  1.10s/it]
# 100% 5/5 [00:01<00:00,  2.72it/s]
# [~] Separating main vocals from backup vocals...
# 2026-03-09 11:49:38 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 6/6 [00:04<00:00,  1.31it/s]
# 100% 5/5 [00:01<00:00,  4.68it/s]
# [~] De-reverbing vocals...
# 2026-03-09 11:49:45 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 11/11 [00:06<00:00,  1.69it/s]
# 100% 8/8 [00:00<00:00,  9.55it/s]
# [~] Converting vocals...
# [~] Post-processing vocals...
# [~] Pitch-shifting instrumentals...
# [~] Pitch-shifting backup vocals...
# [~] Retrieving song...
# [~] Separating vocals from instrumentals...
# 2026-03-09 11:51:42 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 2026-03-09 11:51:42 - WARNING - audio_separator.separator.separator - Unknown audio subtype MPEG_LAYER_III, defaulting to 16-bit output
# 100% 35/35 [00:40<00:00,  1.16s/it]
# 100% 27/27 [00:07<00:00,  3.58it/s]
# [~] Separating main vocals from backup vocals...
# 2026-03-09 11:52:39 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 35/35 [00:28<00:00,  1.21it/s]
# 100% 27/27 [00:06<00:00,  3.90it/s]
# [~] De-reverbing vocals...
# 2026-03-09 11:53:19 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 68/68 [00:40<00:00,  1.69it/s]
# 100% 52/52 [00:07<00:00,  7.26it/s]
# [~] Converting vocals...
# [~] Post-processing vocals...
# [~] Pitch-shifting instrumentals...
# [~] Pitch-shifting backup vocals...
# [~] Retrieving song...
# [~] Separating vocals from instrumentals...
# 2026-03-09 11:55:22 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 2026-03-09 11:55:22 - WARNING - audio_separator.separator.separator - Unknown audio subtype MPEG_LAYER_III, defaulting to 16-bit output
# 100% 8/8 [00:09<00:00,  1.15s/it]
# 100% 7/7 [00:01<00:00,  3.50it/s]
# [~] Separating main vocals from backup vocals...
# 2026-03-09 11:55:36 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 8/8 [00:06<00:00,  1.28it/s]
# 100% 7/7 [00:01<00:00,  3.98it/s]
# [~] De-reverbing vocals...
# 2026-03-09 11:55:47 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 15/15 [00:08<00:00,  1.75it/s]
# 100% 11/11 [00:01<00:00,  8.54it/s]
# [~] Converting vocals...
# [~] Post-processing vocals...
# [~] Pitch-shifting instrumentals...
# [~] Pitch-shifting backup vocals...
# [~] Retrieving song...
# [~] Separating vocals from instrumentals...
# 2026-03-09 11:57:29 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 2026-03-09 11:57:29 - WARNING - audio_separator.separator.separator - Unknown audio subtype MPEG_LAYER_III, defaulting to 16-bit output
# 100% 23/23 [00:27<00:00,  1.18s/it]
# 100% 18/18 [00:04<00:00,  3.86it/s]
# [~] Separating main vocals from backup vocals...
# 2026-03-09 11:58:07 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 23/23 [00:18<00:00,  1.21it/s]
# 100% 18/18 [00:05<00:00,  3.35it/s]
# [~] De-reverbing vocals...
# 2026-03-09 11:58:36 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 45/45 [00:26<00:00,  1.69it/s]
# 100% 34/34 [00:03<00:00,  8.58it/s]
# [~] Converting vocals...
# [~] Post-processing vocals...
# [~] Pitch-shifting instrumentals...
# [~] Pitch-shifting backup vocals...
# [~] Retrieving song...
# [~] Separating vocals from instrumentals...
# [~] Separating main vocals from backup vocals...
# [~] De-reverbing vocals...
# [~] Converting vocals...
# [~] Post-processing vocals...
# [~] Pitch-shifting instrumentals...
# [~] Pitch-shifting backup vocals...
# [~] Retrieving song...
# [~] Separating vocals from instrumentals...
# [~] Separating main vocals from backup vocals...
# [~] De-reverbing vocals...
# [~] Converting vocals...
# [~] Post-processing vocals...
# [~] Pitch-shifting instrumentals...
# [~] Pitch-shifting backup vocals...
# [~] Retrieving song...
# [~] Separating vocals from instrumentals...
# 2026-03-09 12:04:23 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 2026-03-09 12:04:23 - WARNING - audio_separator.separator.separator - Unknown audio subtype MPEG_LAYER_III, defaulting to 16-bit output
# 100% 2/2 [00:02<00:00,  1.10s/it]
# 100% 2/2 [00:00<00:00,  4.63it/s]
# [~] Separating main vocals from backup vocals...
# 2026-03-09 12:04:28 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 2/2 [00:01<00:00,  1.07it/s]
# 100% 2/2 [00:00<00:00,  4.73it/s]
# [~] De-reverbing vocals...
# 2026-03-09 12:04:32 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 3/3 [00:01<00:00,  1.78it/s]
# 100% 3/3 [00:00<00:00,  9.38it/s]
# [~] Converting vocals...
# [~] Post-processing vocals...
# [~] Pitch-shifting instrumentals...
# [~] Pitch-shifting backup vocals...
# [~] Retrieving song...
# [~] Separating vocals from instrumentals...
# [~] Separating main vocals from backup vocals...
# [~] De-reverbing vocals...
# [~] Converting vocals...
# [~] Post-processing vocals...
# [~] Pitch-shifting instrumentals...
# [~] Pitch-shifting backup vocals...
# [~] Retrieving song...
# [~] Separating vocals from instrumentals...
# [~] Separating main vocals from backup vocals...
# [~] De-reverbing vocals...
# [~] Converting vocals...
# [~] Post-processing vocals...
# [~] Pitch-shifting instrumentals...
# [~] Pitch-shifting backup vocals...
# [~] Retrieving song...
# [~] Separating vocals from instrumentals...
# [~] Separating main vocals from backup vocals...
# [~] De-reverbing vocals...
# [~] Converting vocals...
# [~] Post-processing vocals...
# [~] Pitch-shifting instrumentals...
# [~] Pitch-shifting backup vocals...
# [~] Retrieving song...
# [~] Separating vocals from instrumentals...
# 2026-03-09 12:12:17 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 2026-03-09 12:12:17 - WARNING - audio_separator.separator.separator - Unknown audio subtype MPEG_LAYER_III, defaulting to 16-bit output
# 100% 2/2 [00:02<00:00,  1.08s/it]
# 100% 2/2 [00:00<00:00,  4.84it/s]
# [~] Separating main vocals from backup vocals...
# 2026-03-09 12:12:21 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 2/2 [00:01<00:00,  1.33it/s]
# 100% 2/2 [00:00<00:00,  5.20it/s]
# [~] De-reverbing vocals...
# 2026-03-09 12:12:25 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 3/3 [00:01<00:00,  1.81it/s]
# 100% 3/3 [00:00<00:00,  7.05it/s]
# [~] Converting vocals...
# [~] Post-processing vocals...
# [~] Pitch-shifting instrumentals...
# [~] Pitch-shifting backup vocals...
# [~] Retrieving song...
# [~] Separating vocals from instrumentals...
# [~] Separating main vocals from backup vocals...
# [~] De-reverbing vocals...
# [~] Converting vocals...
# [~] Post-processing vocals...
# [~] Pitch-shifting instrumentals...
# [~] Pitch-shifting backup vocals...
# [~] Retrieving song...
# [~] Separating vocals from instrumentals...
# 2026-03-09 12:14:50 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 2026-03-09 12:14:50 - WARNING - audio_separator.separator.separator - Unknown audio subtype MPEG_LAYER_III, defaulting to 16-bit output
# 100% 2/2 [00:02<00:00,  1.10s/it]
# 100% 2/2 [00:00<00:00,  2.70it/s]
# [~] Separating main vocals from backup vocals...
# 2026-03-09 12:14:55 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 2/2 [00:01<00:00,  1.32it/s]
# 100% 2/2 [00:00<00:00,  4.94it/s]
# [~] De-reverbing vocals...
# 2026-03-09 12:14:59 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 3/3 [00:01<00:00,  1.81it/s]
# 100% 3/3 [00:00<00:00,  9.60it/s]
# [~] Converting vocals...
# [~] Post-processing vocals...
# [~] Pitch-shifting instrumentals...
# [~] Pitch-shifting backup vocals...
# [~] Retrieving song...
# [~] Separating vocals from instrumentals...
# [~] Separating main vocals from backup vocals...
# [~] De-reverbing vocals...
# [~] Converting vocals...
# [~] Post-processing vocals...
# [~] Pitch-shifting instrumentals...
# [~] Pitch-shifting backup vocals...
# [~] Retrieving song...
# [~] Separating vocals from instrumentals...
# [~] Separating main vocals from backup vocals...
# [~] De-reverbing vocals...
# [~] Converting vocals...
# [~] Post-processing vocals...
# [~] Pitch-shifting instrumentals...
# [~] Pitch-shifting backup vocals...
# [~] Retrieving song...
# [~] Separating vocals from instrumentals...
# [~] Separating main vocals from backup vocals...
# [~] De-reverbing vocals...
# [~] Converting vocals...
# [~] Post-processing vocals...
# [~] Pitch-shifting instrumentals...
# [~] Pitch-shifting backup vocals...
# [~] Retrieving song...
# [~] Separating vocals from instrumentals...
# 2026-03-09 12:20:00 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 2026-03-09 12:20:00 - WARNING - audio_separator.separator.separator - Unknown audio subtype MPEG_LAYER_III, defaulting to 16-bit output
# 100% 20/20 [00:22<00:00,  1.15s/it]
# 100% 16/16 [00:03<00:00,  4.26it/s]
# [~] Separating main vocals from backup vocals...
# 2026-03-09 12:20:29 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 20/20 [00:16<00:00,  1.24it/s]
# 100% 16/16 [00:04<00:00,  3.99it/s]
# [~] De-reverbing vocals...
# 2026-03-09 12:20:56 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 40/40 [00:23<00:00,  1.69it/s]
# 100% 30/30 [00:03<00:00,  9.08it/s]
# [~] Converting vocals...
# [~] Post-processing vocals...
# [~] Pitch-shifting instrumentals...
# [~] Pitch-shifting backup vocals...
# [~] Retrieving song...
# [~] Separating vocals from instrumentals...
# 2026-03-09 12:25:48 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 2026-03-09 12:25:48 - WARNING - audio_separator.separator.separator - Unknown audio subtype MPEG_LAYER_III, defaulting to 16-bit output
# 100% 16/16 [00:18<00:00,  1.17s/it]
# 100% 13/13 [00:03<00:00,  3.88it/s]
# [~] Separating main vocals from backup vocals...
# 2026-03-09 12:26:13 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 16/16 [00:13<00:00,  1.20it/s]
# 100% 13/13 [00:03<00:00,  3.71it/s]
# [~] De-reverbing vocals...
# 2026-03-09 12:26:34 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 32/32 [00:18<00:00,  1.70it/s]
# 100% 24/24 [00:02<00:00,  8.30it/s]
# [~] Converting vocals...
# [~] Post-processing vocals...
# [~] Pitch-shifting instrumentals...
# [~] Pitch-shifting backup vocals...
# [~] Retrieving song...
# [~] Separating vocals from instrumentals...
# 2026-03-09 12:37:05 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 3/3 [00:03<00:00,  1.08s/it]
# 100% 3/3 [00:01<00:00,  2.64it/s]
# [~] Separating main vocals from backup vocals...
# 2026-03-09 12:37:11 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 3/3 [00:02<00:00,  1.31it/s]
# 100% 3/3 [00:00<00:00,  4.87it/s]
# [~] De-reverbing vocals...
# 2026-03-09 12:37:16 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 4/4 [00:02<00:00,  1.79it/s]
# 100% 4/4 [00:00<00:00,  9.46it/s]
# [~] Converting vocals...
# [~] Post-processing vocals...
# [~] Pitch-shifting instrumentals...
# [~] Pitch-shifting backup vocals...
# [~] Retrieving song...
# [~] Separating vocals from instrumentals...
# 2026-03-09 12:39:56 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 2026-03-09 12:39:56 - WARNING - audio_separator.separator.separator - Unknown audio subtype MPEG_LAYER_III, defaulting to 16-bit output
# 100% 4/4 [00:04<00:00,  1.22s/it]
# 100% 4/4 [00:00<00:00,  4.58it/s]
# [~] Separating main vocals from backup vocals...
# 2026-03-09 12:40:04 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 4/4 [00:03<00:00,  1.30it/s]
# 100% 4/4 [00:00<00:00,  5.13it/s]
# [~] De-reverbing vocals...
# 2026-03-09 12:40:09 - WARNING - audio_separator.separator.separator - Model converted from onnx to pytorch due to segment size not matching dim_t, processing may be slower.
# 100% 8/8 [00:04<00:00,  1.67it/s]
# 100% 7/7 [00:00<00:00,  9.94it/s]
# [~] Converting vocals...
# [~] Post-processing vocals...
# [~] Pitch-shifting instrumentals...
# [~] Pitch-shifting backup vocals...
